# %%
import datetime
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.dates as mdates

# %%
temps = [66, 70, 69, 80, 68, 67, 72, 73, 70, 57, 63, 78, 70, 67, 53, 75, 67, 70, 81, 76, 79, 75, 76, 58]
damage = [0, 2, 0, 0, 0, 0, 0, 0, 0, 2, 1, 0, 2 ,0, 4, 0, 0, 0, 0, 0, 0, 3, 0, 2]

# %%
fig = plt.figure(1, (8, 5), frameon = False) 
ax = fig.add_axes([0, 0, 1, 1]) 
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_position("zero")
ax.spines['bottom'].set_bounds(20, 80)
ax.spines['left'].set_bounds(0, 4)
                                 
                                 
plt.scatter(temps, damage, label = "Previous launches", marker = 'o', linewidth = 0.1)
plt.xlim(20, 85)
plt.ylim(-0.1, 4.5)
plt.xlabel("O-Ring Temp (F)")
plt.ylabel("Severity of worst failure")
plt.vlines(29, ymin = 0, ymax = 4, color = "r", label = "Planned launch", linestyles = ':')
plt.legend()
plt.savefig("launch.pdf", bbox_inches = "tight")

# %%
print(plt.style.available
# Out:
# ['bmh', 'grayscale', 'seaborn-poster', 'seaborn', 'seaborn-whitegrid', 'seaborn-darkgrid', 'seaborn-dark-palette', 'seaborn-dark', 'dark_background', 'fivethirtyeight', 'seaborn-deep', 'classic', 'seaborn-paper', 'seaborn-talk', 'seaborn-notebook', '_classic_test', 'seaborn-bright', 'seaborn-pastel', 'seaborn-colorblind', 'seaborn-white', 'ggplot', 'seaborn-muted', 'seaborn-ticks']

# %%
data_pd = pd.read_csv("BTCvsSP500.csv")
data = np.array(data_pd[["date", "BTC", "SP500"]])

time = np.array(data_pd["date"].values, dtype = np.datetime64)
BTC = data_pd["BTC"].values
SP = data_pd["SP500"].values

rolling_BTC = pd.rolling_mean(data_pd["BTC"], 10) 
rolling_SP = pd.rolling_mean(data_pd["SP500"], 10)
data_pd.head()
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:8: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(center=False,window=10).mean()
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:9: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(center=False,window=10).mean()
#   if __name__ == '__main__':
#    Unnamed: 0        date    BTC        SP500
# 0           1  2013-02-20  29.65  1511.949951
# 1           2  2013-02-21  29.75  1502.420044
# 2           3  2013-02-22  30.25  1515.599976
# 3           4  2013-02-25  30.40  1487.849976
# 4           5  2013-02-26  31.10  1496.939941

# %%
BTC_time
# Out:
# array(['2013-02-20', '2013-02-21', '2013-02-22', ..., '2017-12-14',
#        '2017-12-15', '2017-12-18'], dtype='datetime64[D]')

# %%
BTC_time = time[0:1218]
BTC_BTC = BTC[0:1218]
BTC_SP = SP[0:1218]



plt.figure(1, (16,10))
plt.plot(BTC_time, BTC_BTC, BTC_time, BTC_SP)

# %%
rolling_BTC = rolling_BTC[0:1218]
rolling_SP = rolling_SP[0:1218]



plt.figure(1, (16,10))
plt.plot(BTC_time, rolling_BTC, BTC_time, rolling_SP)

# %%
dates.date2num(BTC_time[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-172-a6315bff1d54> in <module>()
# ----> 1 dates.date2num(BTC_time[0])
#
# ~/.local/lib/python3.5/site-packages/matplotlib/dates.py in date2num(d)
#     355     """
#     356     if not cbook.iterable(d):
# --> 357         return _to_ordinalf(d)
#     358     else:
#     359         d = np.asarray(d)
#
# ~/.local/lib/python3.5/site-packages/matplotlib/dates.py in _to_ordinalf(dt)
#     218         tzi = UTC
#     219
# --> 220     base = float(dt.toordinal())
#     221
#     222     # If it's sufficiently datetime-like, it will have a `date()` method
#
# AttributeError: 'numpy.datetime64' object has no attribute 'toordinal'

# %%
import matplotlib.dates as dates
r = np.array(data_pd)

new_time = dates.date2num(BTC_time)

years = mdates.YearLocator()   # every year
months = mdates.MonthLocator()  # every month
yearsFmt = mdates.DateFormatter('%Y')



fig, ax = plt.subplots()
fig.set_figheight(10)
fig.set_figwidth(10)

ax.plot(new_time, rolling_BTC)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-168-8df485c87606> in <module>()
#       2 r = np.array(data_pd)
#       3
# ----> 4 new_time = dates.date2num(BTC_time)
#       5
#       6 years = mdates.YearLocator()   # every year
#
# ~/.local/lib/python3.5/site-packages/matplotlib/dates.py in date2num(d)
#     360         if not d.size:
#     361             return d
# --> 362         return _to_ordinalf_np_vectorized(d)
#     363
#     364
#
# /usr/local/lib/python3.5/dist-packages/numpy/lib/function_base.py in __call__(self, *args, **kwargs)
#    2737             vargs.extend([kwargs[_n] for _n in names])
#    2738
# -> 2739         return self._vectorize_call(func=func, args=vargs)
#    2740
#    2741     def _get_ufunc_and_otypes(self, func, args):
#
# /usr/local/lib/python3.5/dist-packages/numpy/lib/function_base.py in _vectorize_call(self, func, args)
# ...

# %%
BTC_time
# Out:
# array(['2013-02-20', '2013-02-21', '2013-02-22', ..., '2018-02-14',
#        '2018-02-15', '2018-02-16'], dtype='datetime64[D]')

# %%
print(BTC_time == np.array(r[:,1], dtype = np.datetime64))
# Out:
# [ True  True  True ...,  True  True  True]

# %%
datemin
# Out:
# numpy.datetime64('2013')

# %%
datemax
# Out:
# numpy.datetime64('2018')

# %%
from numpy import genfromtxt
r = genfromtxt('BTCvsSP500.csv', delimiter=',')

# %%
r = np.recfromcsv('BTCvsSP500.csv', delimiter=',', filling_values=np.nan, case_sensitive=True, deletechars='', replace_space=' ')

# %%
t = []
btc = []
sp = []

for i in range(0, len(r))
# Out:
# b'"2013-02-21"'

# %%
import datetime
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.cbook as cbook

years = mdates.YearLocator()   # every year
months = mdates.MonthLocator()  # every month
yearsFmt = mdates.DateFormatter('%Y')

# Load a numpy record array from yahoo csv data with fields date, open, close,
# volume, adj_close from the mpl-data/example directory. The record array
# stores the date as an np.datetime64 with a day unit ('D') in the date column.


fig, ax = plt.subplots()
ax.plot(r[:,1].astype(np.datetime64), r[:,2])

# format the ticks
ax.xaxis.set_major_locator(years)
ax.xaxis.set_major_formatter(yearsFmt)
ax.xaxis.set_minor_locator(months)

# round to nearest years...
datemin = np.datetime64(r[0,1], 'Y')
datemax = np.datetime64(r[-1,1], 'Y') + np.timedelta64(1, 'Y')


# format the coords message box
ax.format_xdata = mdates.DateFormatter('%Y-%m-%d')
ax.grid(True)

# rotates and right aligns the x labels, and moves the bottom of the
# axes up to make room for them
fig.autofmt_xdate()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-189-89c1fae4328b> in <module>()
#      15
#      16 fig, ax = plt.subplots()
# ---> 17 ax.plot(r[:,1].astype(np.datetime64), r[:,2])
#      18
#      19 # format the ticks
#
# /usr/local/lib/python3.5/dist-packages/numpy/core/records.py in __getitem__(self, indx)
#     497
#     498     def __getitem__(self, indx):
# --> 499         obj = super(recarray, self).__getitem__(indx)
#     500
#     501         # copy behavior of getattr, except that here
#
# IndexError: too many indices for array
